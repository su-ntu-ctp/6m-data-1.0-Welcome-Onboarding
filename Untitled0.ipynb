# %% [markdown]
# <a href="https://colab.research.google.com/github/wanjingzhuo/6m-data-1.0-Welcome-Onboarding/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, GitHub! This is my testing!")
# Out:
# Hello, GitHub! This is my testing!
