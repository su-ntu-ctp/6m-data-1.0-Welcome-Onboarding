# %% [markdown]
# <a href="https://colab.research.google.com/github/Luckycharm88/6m-data-1.0-Welcome-Onboarding/blob/main/First_Time.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, GitHub! This is my first commit.")
# Out:
# Hello, GitHub! This is my first commit.

# %%
print("Hello, Carol! How are you?")
# Out:
# Hello, Carol! How are you?
